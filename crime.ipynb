# %% [markdown]
# # Roberry and Burglary per capita
# This notebook is dedicated to determining which of the Pittsburgh neighborhoods has the least number of robberies and burglaris per capita. That is, for every person in a neighborhood, how many people have been robbed or bugled in that neighborhood?
#
# Using the population from the 2010 census, and the number of each crime from 2010, we can determine which neighborhood you are least likely to get stolen from in!

# %% [markdown]
# I'll start, as always, by importing pandas and reading the CSV (`demographics.csv`) into a dataframe

# %%
import pandas as pd

demos = pd.read_csv("demographics.csv")

demos.head()

# %% [markdown]
# While all this data is certainly fun, we only need the Robbery count, the Burglary count, the population, and the Neighborhood for this submetric:

# %%
cols_to_keep = ["SNAP_All_csv__Robbery__2010_", 
                "SNAP_All_csv__Burglary__2010_", 
                "SNAP_All_csv_Neighborhood", 
                "Pop__2010"
               ]
crime_stats = demos[cols_to_keep]

crime_stats.head()
# Out:
#    SNAP_All_csv__Robbery__2010_  SNAP_All_csv__Burglary__2010_  \
# 0                            23                             66
# 1                            16                             35
# 2                            13                             14
# 3                            16                             20
# 4                            12                             20
#
#   SNAP_All_csv_Neighborhood  Pop__2010
# 0           Central Oakland       6086
# 1             North Oakland      10551
# 2              West Oakland       2604
# 3          Crawford-Roberts       2256
# 4            Strip District        616

# %% [markdown]
# Now let's compile all that down into crimes per capita:

# %%
crime_pc = dict()
neighborhood = "SNAP_All_csv_Neighborhood"
robbery = "SNAP_All_csv__Robbery__2010_"
burglary = "SNAP_All_csv__Burglary__2010_"
population = "Pop__2010"
for idx, row in crime_stats.iterrows():
    crime_pc[row[neighborhood]] = (row[robbery] + row[burglary])/row[population] # crime per capita is defined as the sum of robberies and burglaries divided by the population of the neighborhood
# Out:
# {'Central Oakland': 0.01462372658560631,
#  'North Oakland': 0.004833665055444982,
#  'West Oakland': 0.010368663594470046,
#  'Crawford-Roberts': 0.015957446808510637,
#  'Strip District': 0.05194805194805195,
#  'Central Business District': 0.033342518600165336,
#  'Spring Hill-City View': 0.017749244712990938,
#  'Perry South': 0.02243667068757539,
#  'Summer Hill': 0.0019029495718363464,
#  'Northview Heights': 0.018121911037891267,
#  'Perry North': 0.012592592592592593,
#  'Westwood': 0.005870841487279843,
#  'Beltzhoover': 0.017662337662337664,
#  'Central Lawrenceville': 0.009593931280678269,
#  'South Side Flats': 0.019099590723055934,
#  'Allentown': 0.0252,
#  'South Side Slopes': 0.018087271082975358,
#  'Bluff': 0.00393939393939394,
#  'Fineview': 0.019455252918287938,
#  'Hazelwood': 0.01320361362056984,
#  'Lincoln-Lemington-Belmar': 0.01085398320704485,
#  'East Hills': 0.011991164405175133,
#  'South Oakland': 0.013135735938026272,
#  'Mount Washington': 0.01556995113081032,
#  'Greenfield': 0.006854949273375377,
#  'Squirrel Hill South': 0.0060886829913964265,
#  'Central Northside': 0.01505302771125556,
#  'Spring Garden': 0.013574660633484163,
#  'Troy Hill': 0.023949889462048637,
#  'East Allegheny': 0.033707865168539325,
#  'Stanton Heights': 0.004998913279721799,
#  'Lower Lawrenceville': 0.0149508756941478,
#  'Bloomfield': 0.013622364368633025,
#  'Carrick': 0.016513398595866705,
#  'Point Breeze': 0.00658513640639699,
#  'Duquesne Heights': 0.00865979381443299,
#  'Swisshelm Park': 0.0029390154298310064,
#  'Highland Park': 0.006098514464425333,
#  'Garfield': 0.017414965986394557,
#  'Manchester': 0.012206572769953052,
#  'Upper Lawrenceville': 0.013488197826901461,
#  'Beechview': 0.006772009029345372,
#  'Brookline': 0.0041622521568033906,
#  'Morningside': 0.006873879258816497,
#  'Larimer': 0.028356481481481483,
#  'North Shore': 0.026402640264026403,
#  'Bon Air': 0.009900990099009901,
#  'Banksville': 0.0026544401544401543,
#  'Windgap': 0.008765522279035792,
#  'Friendship': 0.008963585434173669,
#  'Arlington': 0.012306046013911182,
#  'St. Clair': 0.009569377990430622,
#  'Mt. Oliver': 0.0019646365422396855,
#  'Sheraden': 0.01773919607473108,
#  'South Shore': 0.47368421052631576,
#  'Allegheny West': 0.021645021645021644,
#  'Elliott': 0.016799664006719867,
#  'Shadyside': 0.0060366510959396335,
#  'Knoxville': 0.028823058446757407,
#  'Allegheny Center': 0.01822079314040729,
#  'Brighton Heights': 0.01186697943976818,
#  'Crafton Heights': 0.00865233350812795,
#  'Polish Hill': 0.00706436420722135,
#  'Chateau': 0.09090909090909091,
#  'Arlington Heights': 0.036885245901639344,
#  'Squirrel Hill North': 0.003256182346211388,
#  'Terrace Village': 0.018277571251548948,
#  'Bedford Dwellings': 0.012479201331114808,
#  'Regent Square': 0.008620689655172414,
#  'Hays': 0.013812154696132596,
#  'Point Breeze North': 0.008276533592989289,
#  'Marshall-Shadeland': 0.015058745656131061,
#  'Lincoln Place': 0.0037186241090796405,
#  'Overbrook': 0.00823271130625686,
#  'Homewood South': 0.04778156996587031,
#  'Homewood North': 0.025,
#  'Homewood West': 0.023227383863080684,
#  'Oakwood': 0.0038948393378773127,
#  'East Liberty': 0.021639120804225594,
#  'East Carnegie': 0.008771929824561403,
#  'New Homestead': 0.00101010101010101,
#  'Upper Hill': 0.0053475935828877,
#  'Middle Hill': 0.019332161687170474,
#  'Esplen': 0.04983388704318937,
#  'Fairywood': 0.000998003992015968,
#  'Chartiers City': 0.0041928721174004195,
#  'Ridgemont': 0.006211180124223602,
#  'West End': 0.03543307086614173,
#  'California-Kirkbride': 0.017082785808147174,
#  'Glen Hazel': 0.006983240223463687}

# %% [markdown]
# Let's put that back into a dataframe so we can get some more info out of it:

# %%
final_stats = pd.DataFrame.from_dict(crime_pc, orient="index", columns=["Crime Per Capita"])

final_stats.head()
# Out:
#                   Crime Per Capita
# Central Oakland           0.014624
# North Oakland             0.004834
# West Oakland              0.010369
# Crawford-Roberts          0.015957
# Strip District            0.051948

# %% [markdown]
# Let's sort it now:

# %%
sorted_stats = final_stats.sort_values(by="Crime Per Capita", ascending=True)

# %% [markdown]
# And the winner is...

# %%
sorted_stats.iloc[0]
# Out:
# Crime Per Capita    0.000998
# Name: Fairywood, dtype: float64

# %% [markdown]
# Fairywood! Good for Fairywood. As for the rest of the neighborhoods:

# %%
sorted_stats
# Out:
#                 Crime Per Capita
# Fairywood               0.000998
# New Homestead           0.001010
# Summer Hill             0.001903
# Mt. Oliver              0.001965
# Banksville              0.002654
# ...                          ...
# Homewood South          0.047782
# Esplen                  0.049834
# Strip District          0.051948
# Chateau                 0.090909
# South Shore             0.473684
#
# [90 rows x 1 columns]
