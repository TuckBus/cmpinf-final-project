# %% [markdown]
# # Number of compiants per neighboorhood
#
# For this project, I used the Pittsburgh 311 dataset. The goal was to figure out which neighborhood in Pittsburgh is the “best” based on the number of complaints per neighborhood.
# My approach was simple. I looked at how many 311 complaints each neighborhood received in the past year and compared those numbers. To make it fair, I divided the number of complaints by the population of each neighborhood. This gave me a fair comparison, since larger neighborhoods naturally have more complaints.
# I also considered other ideas, like using total complaints (not fair to big neighborhoods) or weighting complaints by severity (too complex for this project). So I decided that complaints per 1,000 residents was the clearest and most balanced metric.

# %% [markdown]
# # Metric
#
# The metric complaints per 1,000 residents measures how often people in each Pittsburgh neighborhood report issues through the city’s 311 system. It’s calculated by dividing the total number of 311 complaints by the neighborhood’s population and multiplying by 1,000. This shows which neighborhoods have fewer reported problems or stronger city services. The data comes from the 311 Service Requests dataset and City of Pittsburgh neighborhood population data.

# %% [markdown]
# # The Best Neighborhood

# %%
import pandas as pd

# Load 311 dataset
complaints = pd.read_csv("311.csv")

# Clean data
complaints['neighborhood'] = complaints['neighborhood'].str.strip().str.title()

# Count complaints per neighborhood
complaint_counts = complaints.groupby('neighborhood').size().reset_index(name='Complaint_Count')

# Assign a default population for calculation
average_population = 8000  
complaint_counts['Population'] = average_population

# Calculate complaints per 1,000 residents
complaint_counts['Complaints_per_1000'] = (complaint_counts['Complaint_Count'] / complaint_counts['Population']) * 1000

# Sort neighborhoods (lowest = best)
ranking = complaint_counts.sort_values('Complaints_per_1000', ascending=True)

# Display all neighborhoods
print("All Neighborhoods Ranked by Complaints per 1,000 Residents:\n")
for i, row in ranking.iterrows():
    print(f"{i+1}. {row['neighborhood']} — {row['Complaints_per_1000']:.2f} complaints per 1,000 residents")
# Out:
# All Neighborhoods Ranked by Complaints per 1,000 Residents:
#
# 5. Arlington Heights — 2.00 complaints per 1,000 residents
# 36. Glen Hazel — 7.25 complaints per 1,000 residents
# 59. Northview Heights — 11.00 complaints per 1,000 residents
# 53. Mount Oliver Borough — 11.12 complaints per 1,000 residents
# 21. Chartiers City — 12.38 complaints per 1,000 residents
# 68. Ridgemont — 12.50 complaints per 1,000 residents
# 27. East Carnegie — 15.88 complaints per 1,000 residents
# 79. St. Clair — 19.50 complaints per 1,000 residents
# 56. New Homestead — 19.75 complaints per 1,000 residents
# 22. Chateau — 21.50 complaints per 1,000 residents
# 2. Allegheny West — 22.62 complaints per 1,000 residents
# 83. Swisshelm Park — 22.88 complaints per 1,000 residents
# 12. Bon Air — 24.25 complaints per 1,000 residents
# 31. Esplen — 25.25 complaints per 1,000 residents
# 88. West End — 25.50 complaints per 1,000 residents
# 60. Oakwood — 27.12 complaints per 1,000 residents
# 32. Fairywood — 28.00 complaints per 1,000 residents
# 38. Hays — 28.75 complaints per 1,000 residents
# 82. Summer Hill — 29.25 complaints per 1,000 residents
# 91. Windgap — 36.50 complaints per 1,000 residents
# 67. Regent Square — 38.25 complaints per 1,000 residents
# 34. Friendship — 40.00 complaints per 1,000 residents
# 15. California-Kirkbride — 42.12 complaints per 1,000 residents
# 6. Banksville — 51.88 complaints per 1,000 residents
# 65. Point Breeze North — 53.00 complaints per 1,000 residents
# 90. Westwood — 54.25 complaints per 1,000 residents
# 43. Homewood West — 56.25 complaints per 1,000 residents
# 55. Mt. Oliver — 62.50 complaints per 1,000 residents
# 33. Fineview — 63.00 complaints per 1,000 residents
# 58. North Shore — 66.25 complaints per 1,000 residents
# 72. South Shore — 81.75 complaints per 1,000 residents
# 84. Terrace Village — 84.00 complaints per 1,000 residents
# 46. Lincoln Place — 94.50 complaints per 1,000 residents
# 76. Spring Hill-City View — 94.62 complaints per 1,000 residents
# 23. Crafton Heights — 95.50 complaints per 1,000 residents
# 64. Point Breeze — 100.88 complaints per 1,000 residents
# 4. Arlington — 104.12 complaints per 1,000 residents
# 20. Central Oakland — 109.00 complaints per 1,000 residents
# 52. Morningside — 112.00 complaints per 1,000 residents
# 49. Manchester — 116.00 complaints per 1,000 residents
# 89. West Oakland — 116.12 complaints per 1,000 residents
# 1. Allegheny Center — 119.25 complaints per 1,000 residents
# 28. East Hills — 123.12 complaints per 1,000 residents
# 61. Overbrook — 137.00 complaints per 1,000 residents
# 7. Bedford Dwellings — 142.12 complaints per 1,000 residents
# 30. Elliott — 142.25 complaints per 1,000 residents
# 9. Beltzhoover — 150.50 complaints per 1,000 residents
# 45. Larimer — 161.50 complaints per 1,000 residents
# 71. South Oakland — 163.88 complaints per 1,000 residents
# 86. Upper Hill — 167.50 complaints per 1,000 residents
# 70. Sheraden — 170.38 complaints per 1,000 residents
# 77. Squirrel Hill North — 173.50 complaints per 1,000 residents
# 37. Greenfield — 184.38 complaints per 1,000 residents
# 62. Perry North — 190.50 complaints per 1,000 residents
# 42. Homewood South — 197.75 complaints per 1,000 residents
# 75. Spring Garden — 198.38 complaints per 1,000 residents
# 63. Perry South — 224.38 complaints per 1,000 residents
# 13. Brighton Heights — 227.50 complaints per 1,000 residents
# 39. Hazelwood — 227.62 complaints per 1,000 residents
# 41. Homewood North — 234.38 complaints per 1,000 residents
# 47. Lincoln-Lemington-Belmar — 239.75 complaints per 1,000 residents
# 19. Central Northside — 242.12 complaints per 1,000 residents
# 50. Marshall-Shadeland — 248.62 complaints per 1,000 residents
# 66. Polish Hill — 253.12 complaints per 1,000 residents
# 8. Beechview — 254.88 complaints per 1,000 residents
# 44. Knoxville — 259.75 complaints per 1,000 residents
# 80. Stanton Heights — 311.25 complaints per 1,000 residents
# 57. North Oakland — 314.00 complaints per 1,000 residents
# 69. Shadyside — 316.00 complaints per 1,000 residents
# 29. East Liberty — 341.12 complaints per 1,000 residents
# 14. Brookline — 359.75 complaints per 1,000 residents
# 78. Squirrel Hill South — 365.38 complaints per 1,000 residents
# 81. Strip District — 375.25 complaints per 1,000 residents
# 16. Carrick — 403.75 complaints per 1,000 residents
# 11. Bluff — 455.12 complaints per 1,000 residents
# 24. Crawford-Roberts — 475.75 complaints per 1,000 residents
# 73. South Side Flats — 499.75 complaints per 1,000 residents
# 25. Duquesne Heights — 509.25 complaints per 1,000 residents
# 26. East Allegheny — 510.00 complaints per 1,000 residents
# 3. Allentown — 550.00 complaints per 1,000 residents
# 48. Lower Lawrenceville — 604.25 complaints per 1,000 residents
# 87. Upper Lawrenceville — 703.25 complaints per 1,000 residents
# 51. Middle Hill — 707.75 complaints per 1,000 residents
# 85. Troy Hill — 755.75 complaints per 1,000 residents
# 10. Bloomfield — 915.62 complaints per 1,000 residents
# 74. South Side Slopes — 923.25 complaints per 1,000 residents
# 54. Mount Washington — 1025.00 complaints per 1,000 residents
# 35. Garfield — 1061.62 complaints per 1,000 residents
# 40. Highland Park — 1073.88 complaints per 1,000 residents
# 18. Central Lawrenceville — 1387.38 complaints per 1,000 residents
# 17. Central Business District — 1628.12 complaints per 1,000 residents
